# %% [markdown]
# # **Start and setup of the enviorment**

# %% [markdown]
# *PowerShell (or VS Code > Terminal)*
#
# +python --version
#
# *If not found, install from python.org and tick "Add Python to PATH".*
#
# +python -m pip install --upgrade pip --user
#
# +python -m pip install numpy pandas matplotlib scikit-learn pillow tensorflow keras torch torchvision torchaudio --user

# %%
# test_ml.py — print versions
import sys
import numpy as np
import matplotlib
import sklearn
import tensorflow as tf
import torch

print("Python:", sys.version)
print("NumPy:", np.__version__)
print("Matplotlib:", matplotlib.__version__)
print("scikit-learn:", sklearn.__version__)
print("TensorFlow:", tf.__version__) 
print("PyTorch:", torch.__version__)
# Out:
# Python: 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# NumPy: 2.2.6
# Matplotlib: 3.10.6
# scikit-learn: 1.7.2
# TensorFlow: 2.20.0
# PyTorch: 2.9.1+cpu
